# %% [markdown]
# ## Exercise

# %% [markdown]
# For this exercise, you will be working with the [House Price Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code).
#
# Please grab the train.csv file from Kaggle and explore this dataset. You need to perform explroatory data analysis and see if there is any correlation between the variables and analyze the distribution of the dataset. The question is open-ended and basically you're asked to perform EDA.

# %% [markdown]
# 1- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 3 of your assignment, you need to submit at least one jupyter notebook file and one pdf file.
#
#
# 2- Push your code and project to github and provide the link to your code here. Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %%
import pandas as pd
import numpy as np
import seaborn as sns #import Seaborn
from matplotlib import pyplot as plt
# %matplotlib inline 
house = pd.read_csv("train.csv")
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
house['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.histplot(house['SalePrice'])
plt.title("Sales Prices of houses")
plt.xlabel('Sales Prices')
plt.show()

# %% [markdown]
# - Unimodal and not normal distribution.
# - Right-skewned
# - Show peakedness.

# %% [markdown]
# # Ground living area vs Sales Price

# %% [markdown]
# **Chi-square test**
#
# - Null hypothesis: Ground Living Area is independent with Sales Price. In other words, there is no association between Ground Living Area and Sales Price
#
# - Alternative hypothesis: Ground Living Area is not independent with Sales Price. In other words, there is an association between Ground Living Area and Sales Price

# %%
var = 'GrLivArea' #Ground Living Area
data = pd.concat([house['SalePrice'], house[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000))
plt.show()

# %%
data
# Out:
#       SalePrice  GrLivArea
# 0        208500       1710
# 1        181500       1262
# 2        223500       1786
# 3        140000       1717
# 4        250000       2198
# ...         ...        ...
# 1455     175000       1647
# 1456     210000       2073
# 1457     266500       2340
# 1458     142125       1078
# 1459     147500       1256
#
# [1460 rows x 2 columns]

# %%
data.corr()
# Out:
#            SalePrice  GrLivArea
# SalePrice   1.000000   0.708624
# GrLivArea   0.708624   1.000000

# %%
# Chi-square test 
from scipy.stats import chi2_contingency

stat, p, dof, expected = chi2_contingency(data)
 
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Reject H0: Ground Living Area is not independent with Sales Price of the house')
else:
    print('Accept H0: Ground Living Area is independent with Sales Price of the house')
# Out:
# p value is 0.0
# Reject H0: Ground Living Area is not independent with Sales Price of the house

# %% [markdown]
# # Total square feet of basement area vs Sales Price

# %%
var1 = 'TotalBsmtSF' #Total square feet of basement area
data1 = pd.concat([house['SalePrice'], house[var1]], axis=1)
data1.plot.scatter(x=var1, y='SalePrice', ylim=(0,800000))
plt.title("Distribution of Total Sqr feet of basement area by Sales Price")
plt.xlabel('Total Sqr feet of basement area')
plt.ylabel('Sales Price')
plt.show()

# %%
data1
# Out:
#       SalePrice  TotalBsmtSF
# 0        208500          856
# 1        181500         1262
# 2        223500          920
# 3        140000          756
# 4        250000         1145
# ...         ...          ...
# 1455     175000          953
# 1456     210000         1542
# 1457     266500         1152
# 1458     142125         1078
# 1459     147500         1256
#
# [1460 rows x 2 columns]

# %%
data1.corr()
# Out:
#              SalePrice  TotalBsmtSF
# SalePrice     1.000000     0.613581
# TotalBsmtSF   0.613581     1.000000

# %% [markdown]
# **Chi-square test**
#
# - Null hypothesis: Total square feet of basement area is independent with Sales Price. In other words, there is no association between Total square feet of basement area and Sales Price
#
# - Alternative hypothesis: Total square feet of basement area is not independent with Sales Price. In other words, there is an association between Total square feet of basement area and Sales Price

# %%
stat, p, dof, expected = chi2_contingency(data1)
 
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Reject H0: Total square feet of basement area is not independent with Sales Price of the house')
else:
    print('Accept H0: Total square feet of basement area is independent with Sales Price of the house')
# Out:
# p value is 0.0
# Reject H0: Total square feet of basement area is not independent with Sales Price of the house

# %% [markdown]
# # Overall Quality vs Sales Price

# %%
# Boxplot
var2 = 'OverallQual'
data2 = pd.concat([house['SalePrice'], house[var2]], axis=1)
f, ax = plt.subplots(figsize=(10, 5))
fig = sns.boxplot(x=var2, y="SalePrice", data=data2)
fig.axis(ymin=0, ymax=800000)
plt.title("Distribution of Overall Quality by Sales Price")
plt.xlabel('Overall Quality')
plt.ylabel('Sales Price')
plt.show()

# %%
data2.plot.scatter(x=var2, y='SalePrice')
plt.title("Distribution of Total Sqr feet of basement area by Sales Price")
plt.xlabel('Total Sqr feet of basement area')
plt.ylabel('Sales Price')
plt.show()

# %%
data2
# Out:
#       SalePrice  OverallQual
# 0        208500            7
# 1        181500            6
# 2        223500            7
# 3        140000            7
# 4        250000            8
# ...         ...          ...
# 1455     175000            6
# 1456     210000            6
# 1457     266500            7
# 1458     142125            5
# 1459     147500            5
#
# [1460 rows x 2 columns]

# %%
data2.corr()
# Out:
#              SalePrice  OverallQual
# SalePrice     1.000000     0.790982
# OverallQual   0.790982     1.000000

# %% [markdown]
# **Chi-square test**
#
# - Null hypothesis: Overall Quality is independent with Sales Price. In other words, there is no association between Overall Quality and Sales Price
#
# - Alternative hypothesis: Overall Quality is not independent with Sales Price. In other words, there is an association between Overall Quality and Sales Price

# %%
from scipy.stats import chi2_contingency

stat, p, dof, expected = chi2_contingency(data2)
 
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Reject H0: Overall Quality is not independent with Sales Price of the house')
else:
    print('Accept H0: Overall Quality is independent with Sales Price of the house')
# Out:
# p value is 1.0
# Accept H0: Overall Quality is independent with Sales Price of the house

# %% [markdown]
# # Github

# %% [markdown]
# https://github.com/realanguyen96/Assignment3-3.git
